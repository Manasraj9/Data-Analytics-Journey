# %%
import matplotlib.pyplot as plt

a = [20,30,40,50,0,30,40,30,40,70,75,80,85,88,70,80,40,20]

plt.stem(a,linefmt="--",markerfmt="D", bottom=0, orientation = "horizontal")
plt.show()

# %%
import pandas as pd
data = pd.read_excel("ESD.xlsx")
df = pd.DataFrame(data)
# print(df)
df2 =df.head(30)
plt.stem(df2["Age"])
plt.plot(df2["Age"])
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = sns.load_dataset("tips")
#print(data)
sns.histplot(data, x="day",hue="sex", kde=True)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = sns.load_dataset("titanic")
#print(data)
sns.histplot(data=data, x="age",hue="who", kde=True, bins=8)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = sns.load_dataset("tips")
sns.countplot(data, x="day")
plt.show()

# %%
data = pd.read_excel("ESD.xlsx")
sns.countplot(data, x="Ethnicity",hue="Gender",palette="GnBu")
plt.show()
